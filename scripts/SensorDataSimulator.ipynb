-- %%
%sql
select json_payload.cow_id, 
      time_serie_event,
      json_payload.sensor_id
      ,
      json_payload.value      
from (
select id,
        time_serie_event,
        from_json(cast(payload as string),'STRUCT<cow_id: STRING, sensor_id: STRING, sensor_type: STRING, unit: STRING, value: DOUBLE>') as json_payload
from dev_farm.brz_sensor.cow_measurements)

-- %%
%sql

select *
from dev_farm.slv_metrics.cow_weight;

-- %%
%sql
select *
from dev_farm.slv_metrics.cow_milk_production

-- %%
select *
from parquet.`/Volumes/dev_farm/brz_sensor/resources/cows.parquet`

-- %%
select *
from parquet.`/Volumes/dev_farm/brz_sensor/resources/sensors.parquet`

-- %%
%python
df = spark.read.parquet("/Volumes/dev_farm/brz_sensor/resources/measurements.parquet")
df.printSchema()

-- %%
select *
from parquet.`/Volumes/dev_farm/brz_sensor/resources/measurements.parquet`
