-- %%
-- ===========================================================
-- FARM OLPT MODEL IN POSTGRE'S 'PUBLIC' SCHEMA
-- ===========================================================

CREATE TABLE PUBLIC.COWS(
ID TEXT PRIMARY KEY ,
NAME TEXT,
BIRTHDATE DATE
);

CREATE TABLE PUBLIC.SENSORS(
ID TEXT PRIMARY KEY,
UNIT TEXT
);

-- ===========================================================
-- GRANT "CRUD" PERMISSIONS TO SERVICE PRINCIPAL TO POSTGRE'S 
-- 'PUBLIC' SCHEMA  
-- ===========================================================

-- Grant USAGE permission on the public schema (required to access objects in it)
GRANT USAGE ON SCHEMA public TO "dfc5fa98-f62b-4473-a251-c1e3a558eceb";

-- Grant CREATE permission on the public schema (allows creating new tables)
GRANT CREATE ON SCHEMA public TO "dfc5fa98-f62b-4473-a251-c1e3a558eceb";

-- Grant read-write access to all existing tables in public schema
GRANT SELECT, INSERT, UPDATE, DELETE ON ALL TABLES IN SCHEMA public TO "dfc5fa98-f62b-4473-a251-c1e3a558eceb";
